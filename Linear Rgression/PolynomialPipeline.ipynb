# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline

# %%
def poly_regression(degree):
    # Load the data
    x_new = np.linspace(-3, 3, 100).reshape(100, 1)
    x_new_poly = poly.transform(x_new)

    poly_features = PolynomialFeatures(degree= degree, include_bias=True)

    lin_reg = LinearRegression()

    pipeline = Pipeline([
        ('poly_features', poly_features), 
        ('lin_reg', lin_reg)
        ])
    
    poly_regression.fit(x_train, y_train)
    y_poly_pred = poly_regression.predict(x_test)

    ### Plotting the data
    plt.plot(x_train, poly_regression.predict(x_poly_train), color = 'b')
    plt.scatter(x_train, y_train, color = 'g')
    plt.plot(x_new, y_new_poly, color = 'r')
    plt.scatter(x_train, y_train, color = 'g')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from turtle import poly
#       2
#       3
#       4 def poly_regression(degree):
#
# ImportError: cannot import name 'poly' from 'turtle' (C:\Users\upend\AppData\Local\Programs\Python\Python312\Lib\turtle.py)
