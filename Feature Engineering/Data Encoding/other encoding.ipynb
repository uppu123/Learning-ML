# %% [markdown]
# 2. Label ENcoding : assign a unique number to every category
#                     code same as one hot encoder

# %% [markdown]
# 3. Ordinal Encoding : numerical values assign kardeta and priority bhi set krdeta
#                       Code same as One hot Encoder

# %% [markdown]
# 4. Target Guided Ordinal Encoding : used to encode categorical variables based on their relationships with the target value
#                                     Target and categorical feature alag alag krke hoti
